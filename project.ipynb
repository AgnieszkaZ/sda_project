# %% [markdown]
# # **IMPORTING THE REQUIRED LIBRARIES**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %% [markdown]
# # **DATA EXPLORATION, ANALIZING AND PREPROCESSING**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#!unzip -uq "drive/My Drive/project/Dataset.zip" -d "drive/My Drive/project"

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_01_20/sensor01_air.txt', header=None)
df1.to_csv("sensor01_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor01_air.txt")
print(df1)
# Out:
#       wavelength  amplitude_a
# 0       0.000001       9.1792
# 1       0.000001       9.2003
# 2       0.000001       9.1968
# 3       0.000001       9.1028
# 4       0.000001       9.0601
# ...          ...          ...
# 2996    0.000002       3.8310
# 2997    0.000002       3.8613
# 2998    0.000002       3.8361
# 2999    0.000002       3.9466
# 3000    0.000002       3.8974
#
# [3001 rows x 2 columns]

# %%
df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_01_20/sensor01_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor01_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor01_izopropanol.txt")
print(df2)
# Out:
#       wavelength  amplitude_i
# 0       0.000001     8.555100
# 1       0.000001     8.675000
# 2       0.000001     8.711600
# 3       0.000001     8.715700
# 4       0.000001     8.679200
# ...          ...          ...
# 2996    0.000002    -0.335950
# 2997    0.000002    -0.199560
# 2998    0.000002    -0.403730
# 2999    0.000002     0.028674
# 3000    0.000002    -0.221990
#
# [3001 rows x 2 columns]

# %%
df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_01_20/sensor01_water.txt', header=None)
df3.to_csv("sensor01_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor01_water.txt")
print(df3)
# Out:
#       wavelength  amplitude_w
# 0       0.000001      8.35700
# 1       0.000001      8.42870
# 2       0.000001      8.44220
# 3       0.000001      8.41440
# 4       0.000001      8.40340
# ...          ...          ...
# 2996    0.000002     -0.51536
# 2997    0.000002     -0.36859
# 2998    0.000002     -0.57172
# 2999    0.000002     -0.19214
# 3000    0.000002     -0.25055
#
# [3001 rows x 2 columns]

# %%
output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.1792     8.555100      8.35700
# 1       0.000001       9.2003     8.675000      8.42870
# 2       0.000001       9.1968     8.711600      8.44220
# 3       0.000001       9.1028     8.715700      8.41440
# 4       0.000001       9.0601     8.679200      8.40340
# ...          ...          ...          ...          ...
# 2996    0.000002       3.8310    -0.335950     -0.51536
# 2997    0.000002       3.8613    -0.199560     -0.36859
# 2998    0.000002       3.8361    -0.403730     -0.57172
# 2999    0.000002       3.9466     0.028674     -0.19214
# 3000    0.000002       3.8974    -0.221990     -0.25055
#
# [3001 rows x 4 columns]

# %%
output.to_csv('drive/MyDrive/project/output.csv')

# %%
fig, ax = plt.subplots()

ax.plot(output.wavelength, output.amplitude_a, color='g', label = 'air amplitude')
ax.plot(output.wavelength, output.amplitude_i, color='r', label = 'izopropanol amplitude')
ax.plot(output.wavelength, output.amplitude_w, color='b', label = 'water amplitude')
ax.legend(title='Amplitude Type', loc='lower left', shadow=False)
ax.set_title('Sensor 01')
ax.set_xlabel('Amplitude')
ax.set_ylabel('Wave length')
ax.xaxis.set_tick_params(rotation=90)
plt.show()

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_02_20/sensor02_air.txt', header=None)
df1.to_csv("sensor02_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor02_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_02_20/sensor02_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor02_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor02_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_02_20/sensor02_water.txt', header=None)
df3.to_csv("sensor02_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor02_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output1 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output1)
output1.to_csv('drive/MyDrive/project/output1.csv')
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.7793     9.254400      9.06070
# 1       0.000001       9.8643     9.301200      9.12380
# 2       0.000001       9.8031     9.251200      9.11590
# 3       0.000001       9.7320     9.273400      9.04310
# 4       0.000001       9.6895     9.199900      8.98600
# ...          ...          ...          ...          ...
# 2996    0.000002       3.5505    -0.394290     -0.61592
# 2997    0.000002       3.8237    -0.215570     -0.76438
# 2998    0.000002       3.6708    -0.296660     -0.46729
# 2999    0.000002       3.8785    -0.117730     -0.33695
# 3000    0.000002       3.8886     0.001783     -0.30843
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_03_20/sensor03_air.txt', header=None)
df1.to_csv("sensor03_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor03_air.txt")

df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_03_20/sensor03_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor03_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor03_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_03_20/sensor03_water.txt', header=None)
df3.to_csv("sensor03_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor03_water.txt")

output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output2 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output2)
output2.to_csv('drive/MyDrive/project/output2.csv')
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       7.8831       7.3432       7.2354
# 1       0.000001       8.0971       7.4798       7.3520
# 2       0.000001       7.9478       7.4810       7.3746
# 3       0.000001       7.9979       7.4719       7.2810
# 4       0.000001       7.9220       7.3330       7.0982
# ...          ...          ...          ...          ...
# 2996    0.000002       2.3074      -1.7470      -1.7755
# 2997    0.000002       2.3935      -1.4242      -1.8028
# 2998    0.000002       2.2550      -1.5681      -1.9613
# 2999    0.000002       2.4935      -1.4371      -1.8007
# 3000    0.000002       2.4934      -1.2094      -1.6964
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_04_20/sensor04_air.txt', header=None)
df1.to_csv("sensor04_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor04_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_04_20/sensor04_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor04_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor04_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_04_20/sensor04_water.txt', header=None)
df3.to_csv("sensor04_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor04_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output3 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output3)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       8.0963       7.4954       7.3714
# 1       0.000001       8.1872       7.6049       7.3794
# 2       0.000001       8.2061       7.5770       7.3017
# 3       0.000001       8.1094       7.4928       7.2528
# 4       0.000001       7.9691       7.4703       7.2032
# ...          ...          ...          ...          ...
# 2996    0.000002       1.5783      -2.4698      -2.7569
# 2997    0.000002       1.7888      -2.5143      -2.8164
# 2998    0.000002       1.3259      -2.5354      -2.8534
# 2999    0.000002       1.6945      -2.2139      -2.6457
# 3000    0.000002       1.9239      -2.2747      -2.4994
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_05_20/sensor05_air.txt', header=None)
df1.to_csv("sensor05_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor05_air.txt")

df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_05_20/sensor05_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor05_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor05_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_05_20/sensor05_water.txt', header=None)
df3.to_csv("sensor05_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor05_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output4 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output4)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.4439       8.9739       8.6370
# 1       0.000001       9.6645       9.0295       8.8197
# 2       0.000001       9.5697       8.9789       8.7279
# 3       0.000001       9.6378       8.9369       8.7620
# 4       0.000001       9.4933       8.9419       8.7683
# ...          ...          ...          ...          ...
# 2996    0.000002       2.8330      -1.4352      -1.7018
# 2997    0.000002       2.9789      -1.3112      -1.4070
# 2998    0.000002       2.7841      -1.4019      -1.6194
# 2999    0.000002       2.9465      -1.0986      -1.5367
# 3000    0.000002       3.0680      -1.1614      -1.3299
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_06_20/sensor06_air.txt', header=None)
df1.to_csv("sensor06_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor06_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_06_20/sensor06_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor06_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor06_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_06_20/sensor06_water.txt', header=None)
df3.to_csv("sensor06_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor06_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output5 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output5)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.4554       8.8085       8.7331
# 1       0.000001       9.6052       9.0038       8.7934
# 2       0.000001       9.6264       8.9254       8.7887
# 3       0.000001       9.5136       8.8786       8.7277
# 4       0.000001       9.4042       8.8290       8.7171
# ...          ...          ...          ...          ...
# 2996    0.000002       2.4787      -1.5332      -1.8323
# 2997    0.000002       2.9384      -1.3984      -1.7141
# 2998    0.000002       2.4859      -1.4084      -1.9062
# 2999    0.000002       2.9317      -1.1342      -1.7105
# 3000    0.000002       2.8220      -1.0098      -1.5242
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_07_20/sensor07_air.txt', header=None)
df1.to_csv("sensor07_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor07_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_07_20/sensor07_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor07_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor07_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_07_20/sensor07_water.txt', header=None)
df3.to_csv("sensor07_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor07_water.txt")

output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output6 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output6)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       8.8064      8.25940       8.1180
# 1       0.000001       8.9714      8.32460       8.2177
# 2       0.000001       8.9747      8.29750       8.0696
# 3       0.000001       8.8461      8.33000       8.1302
# 4       0.000001       8.8265      8.26280       7.9694
# ...          ...          ...          ...          ...
# 2996    0.000002       2.9408     -0.98811      -1.0996
# 2997    0.000002       3.2277     -1.03650      -1.1737
# 2998    0.000002       2.8527     -1.05290      -1.2078
# 2999    0.000002       3.3101     -0.71383      -1.1090
# 3000    0.000002       3.2780     -0.67184      -0.9667
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_08_20/sensor08_air.txt', header=None)
df1.to_csv("sensor08_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor08_air.txt")

df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_08_20/sensor08_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor08_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor08_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_08_20/sensor08_water.txt', header=None)
df3.to_csv("sensor08_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor08_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output7 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output7)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.9081     9.324700      9.16330
# 1       0.000001      10.0010     9.457100      9.24730
# 2       0.000001       9.9366     9.330400      9.21270
# 3       0.000001       9.8126     9.317500      9.13130
# 4       0.000001       9.8773     9.275100      9.07600
# ...          ...          ...          ...          ...
# 2996    0.000002       3.7791    -0.179920     -0.47930
# 2997    0.000002       3.6568    -0.329130     -0.51990
# 2998    0.000002       3.7064    -0.503520     -0.77034
# 2999    0.000002       3.7920    -0.042660     -0.40282
# 3000    0.000002       4.0038     0.063801     -0.28101
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_09_20/sensor09_air.txt', header=None)
df1.to_csv("sensor09_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor09_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_09_20/sensor09_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor09_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor09_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_09_20/sensor09_water.txt', header=None)
df3.to_csv("sensor09_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor09_water.txt")

output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output8 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output8)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       8.6910      8.10310       7.8706
# 1       0.000001       8.7223      8.26410       8.0872
# 2       0.000001       8.7796      8.20800       8.0130
# 3       0.000001       8.6753      8.18220       7.9647
# 4       0.000001       8.6667      8.07940       7.9518
# ...          ...          ...          ...          ...
# 2996    0.000002       2.7312     -1.28480      -1.5635
# 2997    0.000002       2.7287     -1.27890      -1.4177
# 2998    0.000002       2.5725     -1.46690      -1.5810
# 2999    0.000002       2.7335     -0.98814      -1.2834
# 3000    0.000002       2.9142     -1.05080      -1.2185
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv('drive/My Drive/project/Dataset/sesion_10_20/sensor10_air.txt', header=None)
df1.to_csv("sensor10_air.txt", header=['wavelength', 'amplitude_a'], index=False)
# display modified csv file
df1 = pd.read_csv("sensor10_air.txt")


df2=pd.read_csv('drive/My Drive/project/Dataset/sesion_10_20/sensor10_izopropanol.txt', header=None)
# converting data frame to csv
df2.to_csv("sensor10_izopropanol.txt", header=['wavelength', 'amplitude_i'], index=False)
# display modified csv file
df2 = pd.read_csv("sensor10_izopropanol.txt")


df3=pd.read_csv('drive/My Drive/project/Dataset/sesion_10_20/sensor10_water.txt', header=None)
df3.to_csv("sensor10_water.txt", header=['wavelength', 'amplitude_w'], index=False)
# display modified csv file
df3 = pd.read_csv("sensor10_water.txt")


output1 = pd.merge(df1, df2, 
                   on='wavelength', 
                   how='inner')

output9 = pd.merge(output1, df3, 
                   on='wavelength', 
                   how='inner')
print(output9)
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.2124      8.70300      8.39660
# 1       0.000001       9.2734      8.73220      8.53270
# 2       0.000001       9.1703      8.67480      8.40860
# 3       0.000001       9.2478      8.59320      8.46760
# 4       0.000001       9.0771      8.56650      8.32770
# ...          ...          ...          ...          ...
# 2996    0.000002       3.2784     -0.61478     -0.86565
# 2997    0.000002       3.4213     -0.53629     -0.84435
# 2998    0.000002       3.3112     -0.81838     -0.97383
# 2999    0.000002       3.4500     -0.57202     -0.63849
# 3000    0.000002       3.6370     -0.42871     -0.75215
#
# [3001 rows x 4 columns]

# %%
#creating a dataframe with all data
data1 = pd.concat([output, output1, output2, output3, output4, output5, output6, output7, output8, output9])
data1.info()
data1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30010 entries, 0 to 3000
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   wavelength   30010 non-null  float64
#  1   amplitude_a  30010 non-null  float64
#  2   amplitude_i  30010 non-null  float64
#  3   amplitude_w  27009 non-null  float64
# dtypes: float64(4)
# memory usage: 1.1 MB
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.1792      8.55510      8.35700
# 1       0.000001       9.2003      8.67500      8.42870
# 2       0.000001       9.1968      8.71160      8.44220
# 3       0.000001       9.1028      8.71570      8.41440
# 4       0.000001       9.0601      8.67920      8.40340
# ...          ...          ...          ...          ...
# 2996    0.000002       3.2784     -0.61478     -0.86565
# 2997    0.000002       3.4213     -0.53629     -0.84435
# 2998    0.000002       3.3112     -0.81838     -0.97383
# ...

# %%
data1.isnull().sum()
# Out:
# wavelength        0
# amplitude_a       0
# amplitude_i       0
# amplitude_w    3001
# dtype: int64

# %%
data1[data1['amplitude_w'].isnull()]
# Out:
#       wavelength  amplitude_a  amplitude_i  amplitude_w
# 0       0.000001       9.2124      8.70300          NaN
# 1       0.000001       9.2734      8.73220          NaN
# 2       0.000001       9.1703      8.67480          NaN
# 3       0.000001       9.2478      8.59320          NaN
# 4       0.000001       9.0771      8.56650          NaN
# ...          ...          ...          ...          ...
# 2996    0.000002       3.2784     -0.61478          NaN
# 2997    0.000002       3.4213     -0.53629          NaN
# 2998    0.000002       3.3112     -0.81838          NaN
# 2999    0.000002       3.4500     -0.57202          NaN
# 3000    0.000002       3.6370     -0.42871          NaN
#
# [3001 rows x 4 columns]

# %%
data=data1.dropna(subset=['amplitude_w'])

# %%
data.isnull().sum()
# Out:
# wavelength     0
# amplitude_a    0
# amplitude_i    0
# amplitude_w    0
# dtype: int64

# %%
#Detecting the outliers

box = px.box(data, y=['amplitude_a','amplitude_i', 'amplitude_w'])
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.describe()
# Out:
#          wavelength   amplitude_a   amplitude_i   amplitude_w
# count  2.700900e+04  27009.000000  27009.000000  27009.000000
# mean   1.500000e-06      0.728393     -1.844162     -1.802262
# std    8.663301e-08      4.895526      6.971331      6.561551
# min    1.350000e-06     -8.798200    -16.165000    -14.673000
# 25%    1.425000e-06     -3.263900     -6.949700     -6.906200
# 50%    1.500000e-06      0.936390     -1.709600     -1.935600
# 75%    1.575000e-06      4.713100      4.511000      4.244500
# max    1.650000e-06     10.003000      9.551500      9.284900

# %% [markdown]
# # **ALGORITHMS AND MODEL TRAINING FOR IZOPROPANOL AMPLITUDE:**

# %%
y = data1['amplitude_i']
X = data1.drop(['amplitude_i', 'amplitude_w'], axis=1)

# %%
#Split the dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#       wavelength  amplitude_a  amplitude_i
# 0       0.000001       9.4439     8.973900
# 0       0.000001       9.4439     7.343200
# 0       0.000001       9.4439     8.103100
# 0       0.000001       9.4439     8.703000
# 0       0.000001       9.4439     8.703000
# ...          ...          ...          ...
# 3000    0.000002       3.2780    -1.009800
# 3000    0.000002       3.2780    -2.274700
# 3000    0.000002       3.2780    -0.221990
# 3000    0.000002       3.2780     0.063801
# 3000    0.000002       3.2780    -0.671840
#
# [196738 rows x 3 columns]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (24008, 2) (24008,)
# (6002, 2) (6002,)

# %% [markdown]
#  Fit a model linear regression
#
# ---

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
model.score(X_train, y_train)
# Out:
# 0.8633055671548693

# %%
model.score(X_train, y_train)
# Out:
# 0.8633055671548693

# %%
#Comparison of the prediction and actual graph
predict1=lm.predict(df1)
print(predict1)
plt.plot(df2.wavelength, predict1, label = 'prediction')
plt.plot(df2.wavelength, df2.amplitude_i, label = 'observation')
plt.legend(loc="lower left")

plt.savefig('ii_prediction.png')
# Out:
# [10.62180611 10.67649331 10.57608794 ... -3.84310094 -3.71488417
#  -3.5411131 ]

# %%
import pickle

with open('model_i','wb') as file:
    pickle.dump(lm,file)

# %% [markdown]
# # **ALGORITHMS AND MODEL TRAINING FOR WATER AMPLITUDE:**

# %%
y = data['amplitude_w']
X = data.drop(['amplitude_w', 'amplitude_i'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
model.score(X_train, y_train)
# Out:
# 0.8897104768496049

# %%
model.score(X_train, y_train)
# Out:
# 0.8897104768496049

# %%
#Comparison of the prediction and actual graph
predict1=lm.predict(df1)
print(predict1)
plt.plot(df3.wavelength, predict1, color = 'r', label='prediction')
plt.plot(df3.wavelength, df3.amplitude_w, color = 'g', label='observation')
plt.legend(loc="lower left")

plt.savefig('ww_prediction.png')
# Out:
# [10.12310588 10.17371109 10.08018145 ... -3.97393926 -3.85499955
#  -3.69372408]
